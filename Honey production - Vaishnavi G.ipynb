# %% [markdown]
# # Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.

# %% [markdown]
# # 1. Import required libraries and read the dataset.

# %%
#Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the dataset
df=pd.read_csv("honeyproduction.csv")
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
#Checking first few samples
a=df.sample(20)
a
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 249    PA   27000.0           50   1350000.0    419000.0        1.44
# 292    SD  215000.0          105  22575000.0  13545000.0        1.01
# 305    CA  400000.0           75  30000000.0   9300000.0        0.86
# 402    MS   15000.0           92   1380000.0    166000.0        0.91
# 525    MO   11000.0           52    572000.0     92000.0        1.80
# 113    NC   11000.0           49    539000.0    243000.0        1.43
# 562    MI   74000.0           64   4736000.0   2084000.0        1.81
# 155    NY   53000.0           70   3710000.0   1781000.0        0.79
# 371    OH   14000.0           56    784000.0    282000.0        1.40
# 48     FL  228000.0          102  23256000.0   4186000.0        0.53
# 198    NM   11000.0           44    484000.0    252000.0        1.10
# 236    MS   21000.0           69   1449000.0    246000.0        1.29
# 214    WV    9000.0           51    459000.0    151000.0        1.32
# ...

# %%
#Checking shape of the dataframe
a.shape
# Out:
# (20, 8)

# %%
#Checking info of the dataframe
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 249 to 328
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        20 non-null     object
#  1   numcol       20 non-null     float64
#  2   yieldpercol  20 non-null     int64
#  3   totalprod    20 non-null     float64
#  4   stocks       20 non-null     float64
#  5   priceperlb   20 non-null     float64
#  6   prodvalue    20 non-null     float64
#  7   year         20 non-null     int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# # 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
df.columns #Checking columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')

# %%
df.groupby(by ='year')['year'].count().plot(kind='pie',autopct='%.2f')  #using groupby, visualizing piechart for percentage distribution of each year
# Out:
# <Axes: ylabel='year'>

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(x=df['priceperlb'],kind='hist',bins=30,kde=True)    #using displot, plotting the distribution of variable
plt.show()

# %%
## FINDINGS:

#    From the above chart we can observe that the 1.5 ['priceperlb'] has the highest count compared to the other.
#    From the above plot for ['priceperlb']and the distribution of the graph is peakin somepoint.
#    Where the [pricerperlb] value is between 1.3 to 1.5 and count value is between 50 to 60.
#    So the graph is positively Skewed..

# %% [markdown]
# # 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
df.plot(kind='scatter',x='numcol',y='prodvalue')   #using scatterplot, plotting the relationship between variables
# Out:
# <Axes: xlabel='numcol', ylabel='prodvalue'>

# %%
## FINDINGS:

#   The relationship between 'numcol'vs'prodvalue'is directly related with then representationof graph.
#   The of 'numcol' and 'prodvalue' is merged in somepoint.
#   The graph values is also gradually increasing.
#   The data is equally spread between 'numcol' and 'prodval'

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(12,5))      #using Boxplot, plotting the categorical variables relationship
sns.boxenplot(x=df['year'],y=df['prodvalue'])
# Out:
# <Axes: xlabel='year', ylabel='prodvalue'>

# %%
##  FINDINGS:
#     From this categorical plotting'numcol', 'totalprod' and 'prodvalue' are positively skewed and 
#    'yieldpercol' seems to be normally distributed
#    'totalprod' vs 'numcol' and 'totalprod' vs 'prodvalue' seems to be directly(positively) realted.
#     From the belw plot year 2010 has outlier value

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
plt.figure(figsize=(12,5))   #using pairplot, visualizing the relationship of multiple pairs of variables
sns.pairplot(df[['numcol', 'yieldpercol','totalprod', 'prodvalue','year']],hue='year')

# %%
df[['prodvalue']].kurtosis()
# Out:
# prodvalue    19.316621
# dtype: float64

# %%
## FINDINGS:

#   'numcol','totalprod','prodvalue' are positively skewed.
#   'yieldpercol' is normally distributed graph
#   So the 'numcol','totalprod','prodvalue' are positively skewed with each other.
#   'product value' has tall and sharp peak and is leptokurtic
#   product value and numcol,totalproduct and numcol is related Linearly

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
df.columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')

# %%
sns.heatmap(df[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']].corr(),annot=True,cbar=True) #using heatmap visualizing the correlation between columns
# Out:
# <Axes: >

# %%
##  FINDINGS:
#     'numcol' and 'total product' is highly related with a correlation value of 95%
#     'yieldpercol' is least related with priceperlb with a negative correlation of -36%
